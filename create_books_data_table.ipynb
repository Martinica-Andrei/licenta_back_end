# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect('sqlite.db')

df = pd.read_csv('datasets/amazon/books_data_reordered.csv')
df.to_sql('book_data', con, if_exists='replace', index=False)

cur = con.cursor()
cur.execute("create virtual table book_fts using fts5(title);")
cur.execute("insert into book_fts (title) select title from book_data;")
con.commit()

# %%
# Out:
#                                                     Title  \
# 0                " Film technique, " and, " Film acting "
# 1       " We'll Always Have Paris": The Definitive Gui...
# 2       "... And Poetry is Born ..." Russian Classical...
# 3            "A Titanic hero" Thomas Andrews, shipbuilder
# 4       "A Truthful Impression of the Country": Britis...
# ...                                                   ...
# 206706                           william the vehicle king
# 206707                           with an everlasting love
# 206708                                work and Motivation
# 206709                             www.whitbread.org/book
# 206710  xBase Programming for the True Beginner: An In...
#
#                                               description  \
# 0       FILM TECHNIQUE AND FILM ACTING- The Cinema Wri...
# 1       This ultimate compilation of more than 11,000 ...
# 2       A selection of Russian poems in Russian with a...
# 3                                                     NaN
# 4       An examination of the writings of travelers to...
# ...                                                   ...
# 206706  William plays on the rug with a multitude of c...
# 206707  This allegorical novel explores the love of Go...
# 206708  This book provides a unique behavioral science...
# 206709                                                NaN
# 206710                                                NaN
#
#                                                   authors  \
# 0                                      ['V. I. Pudovkin']
# 1         ['Robert A. Nowlan', 'Gwendolyn Wright Nowlan']
# 2                        ['Aleksandr Sergeevich Pushkin']
# 3                                     ['Shan F. Bullock']
# 4       ['Nicholas J. Clifford', 'Nicholas Rowland Cli...
# ...                                                   ...
# 206706                                ['Laura P. Newton']
# 206707                                     ['Kay Arthur']
# 206708                                 ['Gary P. Latham']
# 206709                                                NaN
# 206710            ['Eugene Kaluzniacky', 'Vijay Kanabar']
#
#                                                     image  \
# 0       http://books.google.com/books/content?id=IKbBb...
# 1       http://books.google.com/books/content?id=H1YqN...
# 2                                                     NaN
# 3       http://books.google.com/books/content?id=DoQDA...
# 4       http://books.google.com/books/content?id=LYhkk...
# ...                                                   ...
# 206706  http://books.google.com/books/content?id=p3AbA...
# 206707  http://books.google.com/books/content?id=2A8fF...
# 206708  http://books.google.com/books/content?id=LmApk...
# 206709                                                NaN
# 206710  http://books.google.com/books/content?id=HtcFA...
#
#                                               previewLink  \
# 0       http://books.google.nl/books?id=IKbBbMxeJDEC&d...
# 1       http://books.google.com/books?id=H1YqNQAACAAJ&...
# 2       http://books.google.nl/books?id=IWRhwgEACAAJ&d...
# 3       http://books.google.com/books?id=DoQDAAAAYAAJ&...
# 4       http://books.google.com/books?id=LYhkk3S586AC&...
# ...                                                   ...
# 206706  http://books.google.com/books?id=p3AbAQAAMAAJ&...
# 206707  http://books.google.com/books?id=2A8fFSfhdSEC&...
# 206708  http://books.google.com/books?id=LmApklWApCQC&...
# 206709                                                NaN
# 206710  http://books.google.com/books?id=HtcFAAAACAAJ&...
#
#                                        publisher publishedDate  \
# 0                                     Sims Press       2008-11
# 1                                      Perennial          1994
# 2                                            NaN          1984
# 3                                            NaN          1913
# 4                   University of Michigan Press          2001
# ...                                          ...           ...
# 206706  Simon & Schuster Books For Young Readers          1987
# 206707                  Harvest House Publishers    1999-07-01
# 206708                                      SAGE          2012
# 206709                                       NaN           NaN
# 206710                         McGraw-Hill/Irwin    1995-11-01
#
#                                                  infoLink  \
# 0       http://books.google.nl/books?id=IKbBbMxeJDEC&d...
# 1       http://books.google.com/books?id=H1YqNQAACAAJ&...
# 2       http://books.google.nl/books?id=IWRhwgEACAAJ&d...
# 3       https://play.google.com/store/books/details?id...
# 4       http://books.google.com/books?id=LYhkk3S586AC&...
# ...                                                   ...
# 206706  http://books.google.com/books?id=p3AbAQAAMAAJ&...
# 206707  http://books.google.com/books?id=2A8fFSfhdSEC&...
# 206708  http://books.google.com/books?id=LmApklWApCQC&...
# 206709                                                NaN
# 206710  http://books.google.com/books?id=HtcFAAAACAAJ&...
#
#                       categories  ratingsCount
# 0                      ['Drama']           NaN
# 1                  ['Reference']           NaN
# 2             ['Russian poetry']           NaN
# 3                            NaN           NaN
# 4                    ['History']           NaN
# ...                          ...           ...
# 206706                  ['Toys']           NaN
# 206707              ['Religion']           4.0
# 206708  ['Business & Economics']           NaN
# 206709                       NaN           NaN
# 206710             ['Computers']           NaN
#
# [206711 rows x 10 columns]
